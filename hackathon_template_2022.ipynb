# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임 -> 런타임 연결 해제 및 삭제"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
#  *    "런타임 -> 런타임 다시시작"은 클라우드 스토리지에 저장된 모델은 유지됨
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 6시 (단, 발표자료는 12시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2022_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 테스트 데이터 셋 분류 정확도
#  *  model.evaluate(x_test, y_test)
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드가 적발될 경우
# *  Pre-trained 모델을 사용한 경우 (transfer learning 포함)
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예. 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

from tensorflow import keras
from keras.utils import np_utils
from keras import datasets, layers, models

# 데이터셋 로드 (MNIST, fashion-MNIST, Kujushiji-MNIST, MNIST_corrupted (test only))
train_ds, test_ds = tfds.load('mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)

train_ds2, test_ds2 = tfds.load('fashion_mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds2['label'] += 10;
test_ds2['label'] += 10;

train_ds3, test_ds3 = tfds.load('kmnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds3['label'] += 20;
test_ds3['label'] += 20;

test_ds4 = tfds.load('mnist_corrupted/zigzag', split='test', shuffle_files=False, batch_size=-1)

# 데이터셋 병합 (training: 180,000개, test: 40,000개)
x_train = np.append(np.append(train_ds['image'], train_ds2['image'], 0), train_ds3['image'], 0);
y_train = np.append(np.append(train_ds['label'], train_ds2['label'], 0), train_ds3['label'], 0);

x_test = np.append(np.append(np.append(test_ds['image'], test_ds2['image'], 0), test_ds3['image'], 0), test_ds4['image'], 0);
y_test = np.append(np.append(np.append(test_ds['label'], test_ds2['label'], 0), test_ds3['label'], 0), test_ds4['label'], 0);

# 분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# 총 클래스 개수: 30, 입력 데이터 구조: (28, 28, 1)
num_classes = y_train.shape[1]
input_shape = x_train.shape[1:]
print(num_classes, input_shape)
# Out:
# Downloading and preparing dataset 11.06 MiB (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to ~/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to ~/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to ~/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incompleteX4T0WF/fashion_mnist-train.tfrecord*...:   0%|  …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incompleteX4T0WF/fashion_mnist-test.tfrecord*...:   0%|   …
# Dataset fashion_mnist downloaded and prepared to ~/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 20.26 MiB (download: 20.26 MiB, generated: 31.76 MiB, total: 52.02 MiB) to ~/tensorflow_datasets/kmnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incompleteIHOLMK/kmnist-train.tfrecord*...:   0%|          | 0/60…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incompleteIHOLMK/kmnist-test.tfrecord*...:   0%|          | 0/100…
# Dataset kmnist downloaded and prepared to ~/tensorflow_datasets/kmnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 235.23 MiB (download: 235.23 MiB, generated: Unknown size, total: 235.23 MiB) to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incomplete6LP6LO/mnist_corrupted-train.tfrecord*.…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incomplete6LP6LO/mnist_corrupted-test.tfrecord*..…
# Dataset mnist_corrupted downloaded and prepared to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0. Subsequent calls will reuse this data.
# 30 (28, 28, 1)

# %% [markdown]
# # **2. 데이터 전처리**

# %%
# 데이터 전처리 (예: normalization)
# 원본 데이터와 전처리 후 데이터를 구분하기 위해, 변수명 x_train_after, x_test_after를 변경하지 말 것
x_train_after = x_train / 255
x_test_after = x_test / 255

# %% [markdown]
# # **3. 모델 생성**

# %%
# 순차 모델 생성 (가장 기본구조)
model = keras.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.l2(0.01)))
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.l2(0.01)))
model.add(keras.layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.l2(0.01)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.l2(0.01)))
model.add(keras.layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.l2(0.01)))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.l2(0.01)))
model.add(keras.layers.MaxPooling2D((2, 2)))

model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(1024, activation='relu'))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Dense(num_classes, activation='softmax'))

# 모델 컴파일
# optimizer: 모델을 업데이트 하는 방식
# loss: 모델의 정확도를 판단하는 방식
# metrics: 트레이닝 및 테스팅 성능 모니터링을 위한 평가지표
model.compile(loss='categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])

# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')

# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
model.fit(x_train_after, y_train, batch_size = 128, epochs = 32, shuffle=True, callbacks=[cp_callback], validation_data=(x_test_after, y_test))

model.summary()
# Out:
# Epoch 1/32
# 1407/1407 [==============================] - ETA: 0s - loss: 1.4391 - accuracy: 0.8762
# Epoch 1: val_accuracy improved from -inf to 0.82180, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 36s 16ms/step - loss: 1.4391 - accuracy: 0.8762 - val_loss: 0.7696 - val_accuracy: 0.8218
# Epoch 2/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.3922 - accuracy: 0.9201
# Epoch 2: val_accuracy improved from 0.82180 to 0.89178, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 22s 15ms/step - loss: 0.3921 - accuracy: 0.9201 - val_loss: 0.4643 - val_accuracy: 0.8918
# Epoch 3/32
# 1407/1407 [==============================] - ETA: 0s - loss: 0.3319 - accuracy: 0.9299
# Epoch 3: val_accuracy improved from 0.89178 to 0.89355, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 22s 16ms/step - loss: 0.3319 - accuracy: 0.9299 - val_loss: 0.4482 - val_accuracy: 0.8935
# Epoch 4/32
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.3004 - accuracy: 0.9351
# Epoch 4: val_accuracy did not improve from 0.89355
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.3004 - accuracy: 0.9351 - val_loss: 0.4839 - val_accuracy: 0.8831
# Epoch 5/32
# 1407/1407 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.9389
# Epoch 5: val_accuracy did not improve from 0.89355
# 1407/1407 [==============================] - 22s 16ms/step - loss: 0.2819 - accuracy: 0.9389 - val_loss: 0.4685 - val_accuracy: 0.8861
# Epoch 6/32
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.2679 - accuracy: 0.9410
# Epoch 6: val_accuracy improved from 0.89355 to 0.90592, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 23s 16ms/step - loss: 0.2679 - accuracy: 0.9410 - val_loss: 0.3909 - val_accuracy: 0.9059
# Epoch 7/32
# 1407/1407 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9433
# Epoch 7: val_accuracy did not improve from 0.90592
# 1407/1407 [==============================] - 23s 16ms/step - loss: 0.2565 - accuracy: 0.9433 - val_loss: 0.4259 - val_accuracy: 0.8925
# Epoch 8/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.2479 - accuracy: 0.9452
# Epoch 8: val_accuracy did not improve from 0.90592
# 1407/1407 [==============================] - 23s 16ms/step - loss: 0.2479 - accuracy: 0.9452 - val_loss: 0.4579 - val_accuracy: 0.8896
# Epoch 9/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.2413 - accuracy: 0.9460
# Epoch 9: val_accuracy did not improve from 0.90592
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.2413 - accuracy: 0.9460 - val_loss: 0.4248 - val_accuracy: 0.8970
# Epoch 10/32
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.2351 - accuracy: 0.9475
# Epoch 10: val_accuracy improved from 0.90592 to 0.90935, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 23s 16ms/step - loss: 0.2352 - accuracy: 0.9475 - val_loss: 0.3633 - val_accuracy: 0.9093
# Epoch 11/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.2290 - accuracy: 0.9489
# Epoch 11: val_accuracy did not improve from 0.90935
# 1407/1407 [==============================] - 22s 15ms/step - loss: 0.2290 - accuracy: 0.9489 - val_loss: 0.3877 - val_accuracy: 0.9041
# Epoch 12/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.2248 - accuracy: 0.9500
# Epoch 12: val_accuracy did not improve from 0.90935
# 1407/1407 [==============================] - 22s 15ms/step - loss: 0.2248 - accuracy: 0.9500 - val_loss: 0.4084 - val_accuracy: 0.9006
# Epoch 13/32
# 1407/1407 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9507
# Epoch 13: val_accuracy improved from 0.90935 to 0.91000, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 22s 15ms/step - loss: 0.2209 - accuracy: 0.9507 - val_loss: 0.3708 - val_accuracy: 0.9100
# Epoch 14/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.2166 - accuracy: 0.9512
# Epoch 14: val_accuracy improved from 0.91000 to 0.91752, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 23s 16ms/step - loss: 0.2167 - accuracy: 0.9512 - val_loss: 0.3365 - val_accuracy: 0.9175
# Epoch 15/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.2132 - accuracy: 0.9522
# Epoch 15: val_accuracy did not improve from 0.91752
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.2133 - accuracy: 0.9521 - val_loss: 0.4221 - val_accuracy: 0.8976
# Epoch 16/32
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.2118 - accuracy: 0.9524
# Epoch 16: val_accuracy did not improve from 0.91752
# 1407/1407 [==============================] - 22s 16ms/step - loss: 0.2118 - accuracy: 0.9524 - val_loss: 0.3882 - val_accuracy: 0.9039
# Epoch 17/32
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.2070 - accuracy: 0.9536
# Epoch 17: val_accuracy did not improve from 0.91752
# 1407/1407 [==============================] - 22s 15ms/step - loss: 0.2070 - accuracy: 0.9536 - val_loss: 0.3767 - val_accuracy: 0.9100
# Epoch 18/32
# 1407/1407 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.9537
# Epoch 18: val_accuracy did not improve from 0.91752
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.2048 - accuracy: 0.9537 - val_loss: 0.3950 - val_accuracy: 0.9044
# Epoch 19/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.2025 - accuracy: 0.9542
# Epoch 19: val_accuracy did not improve from 0.91752
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.2026 - accuracy: 0.9542 - val_loss: 0.3588 - val_accuracy: 0.9150
# Epoch 20/32
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.2000 - accuracy: 0.9552
# Epoch 20: val_accuracy did not improve from 0.91752
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.2000 - accuracy: 0.9552 - val_loss: 0.3677 - val_accuracy: 0.9112
# Epoch 21/32
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9555
# Epoch 21: val_accuracy did not improve from 0.91752
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1979 - accuracy: 0.9555 - val_loss: 0.3827 - val_accuracy: 0.9068
# Epoch 22/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1955 - accuracy: 0.9560
# Epoch 22: val_accuracy did not improve from 0.91752
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1955 - accuracy: 0.9560 - val_loss: 0.4040 - val_accuracy: 0.9018
# Epoch 23/32
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1930 - accuracy: 0.9565
# Epoch 23: val_accuracy improved from 0.91752 to 0.92435, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1931 - accuracy: 0.9565 - val_loss: 0.3114 - val_accuracy: 0.9244
# Epoch 24/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1925 - accuracy: 0.9570
# Epoch 24: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 22s 16ms/step - loss: 0.1925 - accuracy: 0.9570 - val_loss: 0.3604 - val_accuracy: 0.9111
# Epoch 25/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1897 - accuracy: 0.9577
# Epoch 25: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1897 - accuracy: 0.9577 - val_loss: 0.3247 - val_accuracy: 0.9202
# Epoch 26/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1896 - accuracy: 0.9578
# Epoch 26: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 22s 15ms/step - loss: 0.1896 - accuracy: 0.9578 - val_loss: 0.3620 - val_accuracy: 0.9152
# Epoch 27/32
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1881 - accuracy: 0.9580
# Epoch 27: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 22s 16ms/step - loss: 0.1881 - accuracy: 0.9580 - val_loss: 0.3344 - val_accuracy: 0.9186
# Epoch 28/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1871 - accuracy: 0.9580
# Epoch 28: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1871 - accuracy: 0.9580 - val_loss: 0.3872 - val_accuracy: 0.9094
# Epoch 29/32
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1860 - accuracy: 0.9582
# Epoch 29: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1860 - accuracy: 0.9582 - val_loss: 0.3260 - val_accuracy: 0.9219
# Epoch 30/32
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1845 - accuracy: 0.9593
# Epoch 30: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 22s 15ms/step - loss: 0.1845 - accuracy: 0.9593 - val_loss: 0.3459 - val_accuracy: 0.9161
# Epoch 31/32
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1843 - accuracy: 0.9591
# Epoch 31: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1843 - accuracy: 0.9591 - val_loss: 0.3766 - val_accuracy: 0.9117
# Epoch 32/32
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1814 - accuracy: 0.9600
# Epoch 32: val_accuracy did not improve from 0.92435
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1815 - accuracy: 0.9599 - val_loss: 0.3375 - val_accuracy: 0.9189
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 1024)              1180672
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 30)                30750
#
# =================================================================
# Total params: 1,497,854
# Trainable params: 1,497,854
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team03'

# 트레이닝된 전체 모델을 저장합니다.
model.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team03'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test_after, y_test)
# Out:
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.3375 - accuracy: 0.9189
# [0.337473601102829, 0.9189249873161316]
